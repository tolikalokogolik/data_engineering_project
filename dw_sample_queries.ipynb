# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql://airflow:airflow@localhost:5432/airflow')

# %% [markdown]
# ### Overview

# %% [markdown]
# ![ERD from pgAdmin4](report_images/pgadmin_erd.png)

# %%
join_all = '''
SELECT 
	tag_profanity_score, popularity_score,
	dim_creation_date.*,
	dim_meme_details.*,
	dim_vision_profanity_scores.*
	FROM public.fact_meme_creation
	LEFT JOIN dim_creation_date on fact_meme_creation.d_date_key = dim_creation_date.date_dim_id
	LEFT JOIN dim_meme_details on fact_meme_creation.d_details_key = dim_meme_details.d_details_id
	LEFT JOIN dim_vision_profanity_scores on fact_meme_creation.d_vprof_key = dim_vision_profanity_scores.d_vprof_id;
'''
df = pd.read_sql(join_all,con=engine).convert_dtypes()
df.describe().T
# Out:
#                       count          mean           std           min  \
# tag_profanity_score  8174.0  1.235044e-01  1.886486e-01  6.974974e-04
# popularity_score     8111.0  5.173061e+01  5.906231e+01  0.000000e+00
# date_dim_id          8019.0  2.013079e+07  2.686754e+04  2.008121e+07
# epoch                8019.0  1.372554e+09  8.374154e+07  1.228867e+09
# day_of_week          8019.0  3.706322e+00  1.907482e+00  1.000000e+00
# day_of_month         8019.0  1.566168e+01  8.787925e+00  1.000000e+00
# week_of_month        8019.0  2.691607e+00  1.267253e+00  1.000000e+00
# week_of_year         8019.0  2.560282e+01  1.449993e+01  1.000000e+00
# month_actual         8019.0  6.296920e+00  3.320684e+00  1.000000e+00
# year_actual          8019.0  2.013014e+03  2.692995e+00  2.008000e+03
# d_details_id         8174.0  4.087500e+03  2.359775e+03  1.000000e+00
# details_year         7674.0  2.007657e+03  2.130368e+01  1.336000e+03
# tag_count            8067.0  7.095575e+00  3.963310e+00  1.000000e+00
# d_vprof_id           8111.0  4.086089e+03  2.357703e+03  1.000000e+00
#
#                               25%           50%           75%           max
# tag_profanity_score  2.208774e-02  4.762449e-02  1.293062e-01  9.999999e-01
# popularity_score     2.000000e+00  2.400000e+01  9.200000e+01  3.010000e+02
# date_dim_id          2.011011e+07  2.013052e+07  2.015120e+07  2.020112e+07
# epoch                1.294704e+09  1.369354e+09  1.449014e+09  1.606176e+09
# day_of_week          2.000000e+00  4.000000e+00  5.000000e+00  7.000000e+00
# day_of_month         8.000000e+00  1.500000e+01  2.300000e+01  3.100000e+01
# week_of_month        2.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# week_of_year         1.300000e+01  2.500000e+01  3.700000e+01  5.300000e+01
# month_actual         3.000000e+00  6.000000e+00  9.000000e+00  1.200000e+01
# year_actual          2.011000e+03  2.013000e+03  2.015000e+03  2.020000e+03
# d_details_id         2.044250e+03  4.087500e+03  6.130750e+03  8.174000e+03
# details_year         2.007000e+03  2.010000e+03  2.014000e+03  2.019000e+03
# tag_count            4.000000e+00  6.000000e+00  9.000000e+00  4.500000e+01
# d_vprof_id           2.048500e+03  4.088000e+03  6.127500e+03  8.171000e+03

# %%
df.sample(25)
# Out:
#       tag_profanity_score  popularity_score  date_dim_id date_actual  \
# 5494             0.448195                 4     20150511  2015-05-11
# 6734             0.027888                 2     20120708  2012-07-08
# 2836             0.014678                 2     20111119  2011-11-19
# 5044             0.050178                 4     20091103  2009-11-03
# 1259             0.213622                 1     20111224  2011-12-24
# 548              0.054353                10     20090606  2009-06-06
# 3189             0.080656                 9     20140410  2014-04-10
# 2008             0.432982                 5     20151228  2015-12-28
# 7902             0.019958                 0     20110312  2011-03-12
# 1711               0.0122                 5     20151124  2015-11-24
# 4730             0.100995                18     20121109  2012-11-09
# 1714             0.039477                16     20110708  2011-07-08
# 3948             0.021562                 0     20120103  2012-01-03
# 211              0.080169                 1     20120310  2012-03-10
# 4188             0.046407                 1     20100222  2010-02-22
# 99                0.04984                19     20110530  2011-05-30
# 7575             0.022388               136     20150704  2015-07-04
# 2459             0.007097                 1     20100121  2010-01-21
# 5096             0.014292                 0     20110512  2011-05-12
# 6389             0.002952                 6     20160701  2016-07-01
# 2578             0.227034               137     20100130  2010-01-30
# 7002              0.07373                11     20100707  2010-07-07
# 6449             0.238821                24     20160628  2016-06-28
# 6073             0.041086                15     20120828  2012-08-28
# 6981              0.02411                85     20090810  2009-08-10
#
#            epoch  day_of_week  day_of_month  week_of_month  week_of_year  \
# 5494  1431302400            1            11              2            20
# 6734  1341705600            7             8              2            27
# 2836  1321660800            6            19              3            46
# 5044  1257206400            2             3              1            45
# 1259  1324684800            6            24              4            51
# 548   1244246400            6             6              1            23
# 3189  1397088000            4            10              2            15
# 2008  1451260800            1            28              4            53
# 7902  1299888000            6            12              2            10
# 1711  1448323200            2            24              4            48
# 4730  1352419200            5             9              2            45
# 1714  1310083200            5             8              2            27
# 3948  1325548800            2             3              1             1
# 211   1331337600            6            10              2            10
# 4188  1266796800            1            22              4             8
# 99    1306713600            1            30              5            22
# 7575  1435968000            6             4              1            27
# 2459  1264032000            4            21              3             3
# 5096  1305158400            4            12              2            19
# 6389  1467331200            5             1              1            26
# 2578  1264809600            6            30              5             4
# 7002  1278460800            3             7              1            27
# 6449  1467072000            2            28              4            26
# 6073  1346112000            2            28              4            35
# 6981  1249862400            1            10              2            33
#
#      week_of_year_iso  ...                               details_origin  \
# 5494       2015-W20-1  ...                                       Tumblr
# 6734       2012-W27-7  ...                                     niconico
# 2836       2011-W46-6  ...                                      Unknown
# 5044       2009-W45-2  ...                                   DeviantArt
# 1259       2011-W51-6  ...                                       Reddit
# 548        2009-W23-6  ...                        Austrian Sex Criminal
# 3189       2014-W15-4  ...                                     niconico
# 2008       2015-W53-1  ...                                      Twitter
# 7902       2011-W10-6  ...                                      YouTube
# 1711       2015-W48-2  ...                                      Fallout
# 4730       2012-W45-5  ...                                      Twitter
# 1714       2011-W27-5  ...  Empire Carpet Commercials from 2002-present
# 3948       2012-W01-2  ...                                     2channel
# 211        2012-W10-6  ...                German TV Commercial: Alpecin
# 4188       2010-W08-1  ...                                      Twitter
# 99         2011-W22-1  ...                                       Brazil
# 7575       2015-W27-6  ...                                       Reddit
# 2459       2010-W03-4  ...                                      YouTube
# 5096       2011-W19-4  ...                              Hark! A Vagrant
# 6389       2016-W26-5  ...                                      Twitter
# 2578       2010-W04-6  ...                                      YouTube
# 7002       2010-W27-3  ...                       Lamb Chop's Play-Along
# 6449       2016-W26-2  ...                                      Unknown
# 6073       2012-W35-2  ...                                       Tumblr
# 6981       2009-W33-1  ...                                   Newgrounds
#
#       tag_count  first_vision_tag d_vprof_id  \
# 5494          3          Forehead       3598
# 6734          8               Dog       5343
# 2836          6              <NA>       5844
# 5044          4        Vertebrate       7645
# 1259         16           Glasses       5780
# 548           7              Chin       7987
# 3189          6    Sports uniform       4423
# 2008          8              <NA>       3099
# 7902          5            Bottle       6417
# 1711         14               Dog       3150
# 4730          8          Forehead       5188
# 1714          8              <NA>       6158
# 3948          7              Food       5749
# 211          14              <NA>       5573
# 4188          6              <NA>       7352
# 99            1             Shirt       6259
# 7575          4              Hair       3483
# 2459          1              <NA>       7432
# 5096          3              Hair       6307
# 6389          5             Smile       2668
# 2578         12          Forehead       7415
# 7002          4   Automotive tire        196
# 6449          6          Forehead       1051
# 6073          5             Joint       5264
# 6981         20           Vehicle       7869
#
#                                                     url          adult  \
# 5494    https://knowyourmeme.com/memes/problematic-fave       UNLIKELY
# 6734  https://knowyourmeme.com/memes/tetsu-the-robot...  VERY_UNLIKELY
# 2836  https://knowyourmeme.com/memes/harmonization-%...  VERY_UNLIKELY
# 5044  https://knowyourmeme.com/memes/omega-kawaii-cl...  VERY_UNLIKELY
# 1259     https://knowyourmeme.com/memes/college-liberal       UNLIKELY
# 548   https://knowyourmeme.com/memes/basement-dad-jo...  VERY_UNLIKELY
# 3189   https://knowyourmeme.com/memes/ichiro-laser-beam       UNLIKELY
# 2008        https://knowyourmeme.com/memes/emo-kylo-ren  VERY_UNLIKELY
# 7902        https://knowyourmeme.com/memes/x-calls-on-y  VERY_UNLIKELY
# 1711             https://knowyourmeme.com/memes/dogmeat  VERY_UNLIKELY
# 4730  https://knowyourmeme.com/memes/nate-silver-dru...  VERY_UNLIKELY
# 1714  https://knowyourmeme.com/memes/dogs-sing-to-th...  VERY_UNLIKELY
# 3948  https://knowyourmeme.com/memes/korokke-in-typhoon  VERY_UNLIKELY
# 211   https://knowyourmeme.com/memes/alpecin-tv-comm...  VERY_UNLIKELY
# 4188            https://knowyourmeme.com/memes/lostiran  VERY_UNLIKELY
# 99    https://knowyourmeme.com/memes/a-banda-mais-xx...       POSSIBLE
# 7575    https://knowyourmeme.com/memes/we-did-it-reddit  VERY_UNLIKELY
# 2459  https://knowyourmeme.com/memes/gamecube-intro-...  VERY_UNLIKELY
# 5096    https://knowyourmeme.com/memes/ooh-mister-darcy  VERY_UNLIKELY
# 6389  https://knowyourmeme.com/memes/spongebob-compa...  VERY_UNLIKELY
# 2578  https://knowyourmeme.com/memes/gingers-do-have...  VERY_UNLIKELY
# 7002  https://knowyourmeme.com/memes/the-song-that-n...  VERY_UNLIKELY
# 6449           https://knowyourmeme.com/memes/stare-kid  VERY_UNLIKELY
# 6073  https://knowyourmeme.com/memes/shit-im-late-fo...  VERY_UNLIKELY
# 6981    https://knowyourmeme.com/memes/the-rock-driving  VERY_UNLIKELY
#
#               spoof        medical       violence           racy
# 5494         LIKELY       POSSIBLE       POSSIBLE       UNLIKELY
# 6734  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY       POSSIBLE
# 2836  VERY_UNLIKELY       POSSIBLE       POSSIBLE       POSSIBLE
# 5044  VERY_UNLIKELY  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 1259    VERY_LIKELY       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 548     VERY_LIKELY       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 3189  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY       UNLIKELY
# 2008       UNLIKELY       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 7902         LIKELY       UNLIKELY  VERY_UNLIKELY       UNLIKELY
# 1711       POSSIBLE       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 4730       UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 1714  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 3948  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 211   VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 4188  VERY_UNLIKELY  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 99         UNLIKELY       UNLIKELY       UNLIKELY       POSSIBLE
# 7575    VERY_LIKELY       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 2459       UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 5096       UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY       UNLIKELY
# 6389         LIKELY  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 2578       POSSIBLE  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 7002  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY  VERY_UNLIKELY
# 6449  VERY_UNLIKELY       UNLIKELY       UNLIKELY  VERY_UNLIKELY
# 6073  VERY_UNLIKELY       UNLIKELY       UNLIKELY         LIKELY
# 6981       UNLIKELY  VERY_UNLIKELY       UNLIKELY  VERY_UNLIKELY
#
# [25 rows x 29 columns]

# %% [markdown]
# ### Grouping statistics by dim_creation_date.year_actual

# %%
query = '''
SELECT 
	dim_creation_date.year_actual, 
	avg(tag_profanity_score) as avg_profanity_score, 
	avg(popularity_score) as avg_popularity_score, 
	count(*) as meme_count
	FROM public.fact_meme_creation
	LEFT JOIN dim_creation_date on fact_meme_creation.d_date_key = dim_creation_date.date_dim_id
	LEFT JOIN dim_meme_details on fact_meme_creation.d_details_key = dim_meme_details.d_details_id
	LEFT JOIN dim_vision_profanity_scores on fact_meme_creation.d_vprof_key = dim_vision_profanity_scores.d_vprof_id
	GROUP by dim_creation_date.year_actual
	Order by count(*) desc
'''
pd.read_sql(query,con=engine).convert_dtypes()
# Out:
#     year_actual  avg_profanity_score  avg_popularity_score  meme_count
# 0          2010              0.12838             46.292704        1169
# 1          2017             0.119218             53.994888         991
# 2          2016             0.109251             53.794709         950
# 3          2011             0.141357             48.177489         936
# 4          2015             0.133639             55.795652         930
# 5          2014             0.105988              52.77204         800
# 6          2009             0.121356             53.180307         787
# 7          2012             0.119677             53.689345         781
# 8          2013             0.122033             51.200323         621
# 9          <NA>             0.151491             30.150327         155
# 10         2008              0.11248             88.823529          34
# 11         2020             0.168081             41.285714           8
# 12         2018             0.269867                 121.0           8
# 13         2019             0.140752                  90.0           4

# %% [markdown]
# ### What are most popular weekdays to add 4chan-sourced memes?

# %%
query = """
SELECT 
	dim_creation_date.day_of_week, 
	avg(tag_profanity_score) as avg_profanity_score, 
	avg(popularity_score) as avg_popularity_score, 
	count(*) as meme_count
	FROM public.fact_meme_creation
	LEFT JOIN dim_creation_date on fact_meme_creation.d_date_key = dim_creation_date.date_dim_id
	LEFT JOIN dim_meme_details on fact_meme_creation.d_details_key = dim_meme_details.d_details_id
	LEFT JOIN dim_vision_profanity_scores on fact_meme_creation.d_vprof_key = dim_vision_profanity_scores.d_vprof_id
	WHERE dim_meme_details.details_origin like %s
	GROUP by dim_creation_date.day_of_week
	Order by count(*) desc
"""
pd.read_sql(query,con=engine, params=['%4chan%']).convert_dtypes()
# Out:
#    day_of_week  avg_profanity_score  avg_popularity_score  meme_count
# 0            7             0.184416             50.479167          96
# 1            4             0.200423             56.212766          95
# 2            3             0.169295              53.82716          83
# 3            1              0.18479             54.311688          77
# 4            2             0.212872             68.081081          74
# 5            6             0.176558             47.940299          67
# 6            5             0.159149             57.365079          64
# 7         <NA>              0.21196             38.769231          13
